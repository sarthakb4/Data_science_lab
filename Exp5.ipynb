# %% [markdown]
# <a href="https://colab.research.google.com/github/sarthakb4/Data_science_lab/blob/main/Exp5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
   # Import required libraries
import pandas as pd
import numpy as np

# Load Iris dataset (from sklearn)
from sklearn.datasets import load_iris

# Convert dataset into DataFrame
iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# Add species column
df['species'] = iris.target
df['species'] = df['species'].map({0: 'Setosa', 1: 'Versicolor', 2: 'Virginica'})

# Display first 5 rows
print("First 5 rows:")
print(df.head())

# -------------------------------
# Filtering Data
# -------------------------------

# Example: Filter flowers with petal length > 5
filtered_data = df[df['petal length (cm)'] > 5]
print("\nFiltered Data (Petal Length > 5):")
print(filtered_data)

# -------------------------------
# Grouping Data
# -------------------------------

grouped = df.groupby('species')

# -------------------------------
# Aggregate Statistics
# -------------------------------

print("\nMean values:")
print(grouped.mean())

print("\nMaximum values:")
print(grouped.max())

print("\nMinimum values:")
print(grouped.min())

print("\nCount of each species:")
print(grouped.count())
# Out:
# First 5 rows:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  Setosa
# 1  Setosa
# 2  Setosa
# 3  Setosa
# 4  Setosa
#
# Filtered Data (Petal Length > 5):
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 83                 6.0               2.7                5.1               1.6
# 100                6.3               3.3                6.0               2.5
# 101                5.8               2.7                5.1               1.9
# ...
